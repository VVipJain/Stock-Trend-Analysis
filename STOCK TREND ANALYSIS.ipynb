# %% [markdown]
# STOCK ANALYSIS PROJECT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime

# %%
df = pd.read_csv("NFLX.csv")

# %%
sns.set(rc = {"figure.figsize" : (10,5)})

# %%
df["Date"] = pd.to_datetime(df["Date"])
df = df.set_index(df["Date"])
df
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2018-02-05 2018-02-05  262.000000  267.899994  250.029999  254.259995
# 2018-02-06 2018-02-06  247.699997  266.700012  245.000000  265.720001
# 2018-02-07 2018-02-07  266.579987  272.450012  264.329987  264.559998
# 2018-02-08 2018-02-08  267.079987  267.619995  250.000000  250.100006
# 2018-02-09 2018-02-09  253.850006  255.800003  236.110001  249.470001
# ...               ...         ...         ...         ...         ...
# 2022-01-31 2022-01-31  401.970001  427.700012  398.200012  427.140015
# 2022-02-01 2022-02-01  432.959991  458.480011  425.540009  457.130005
# 2022-02-02 2022-02-02  448.250000  451.980011  426.480011  429.480011
# 2022-02-03 2022-02-03  421.440002  429.260010  404.279999  405.600006
# 2022-02-04 2022-02-04  407.309998  412.769989  396.640015  410.170013
#
#              Adj Close    Volume
# Date
# 2018-02-05  254.259995  11896100
# 2018-02-06  265.720001  12595800
# ...

# %% [markdown]
# VOLUME OF STOCKS VS TIME

# %%
sns.lineplot(x = df.index , y = df["Volume"], label = "Volume")
plt.title("VOLUME VS TIME")
# Out:
# Text(0.5, 1.0, 'VOLUME VS TIME')

# %%
df.plot(y = ["High" , "Open" , "Close"] , title = "STOCK PRICE ANALYSIS")
# Out:
# <Axes: title={'center': 'STOCK PRICE ANALYSIS'}, xlabel='Date'>

# %% [markdown]
# VOLUME TRADED OVER DAY , MONTH AND YEAR

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3,figsize = (15,13))
df.groupby(df.index.day).mean().plot(y = "Volume" , ax = ax1 , xlabel = "Day")
df.groupby(df.index.month).mean().plot(y = "Volume" , ax = ax2 , xlabel = "Months")
df.groupby(df.index.year).mean().plot(y = "Volume" , ax = ax3 , xlabel = "Year")
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# DATES WITH HIGHEST STOCK PRICES

# %%
a = df.sort_values(by = "High" , ascending = False).head(5)
a["High"]
# Out:
# Date
# 2021-11-17    700.989990
# 2021-11-19    694.159973
# 2021-11-18    691.739990
# 2021-10-29    690.969971
# 2021-11-01    689.969971
# Name: High, dtype: float64

# %% [markdown]
# DATES WITH LOWEST STOCK PRICES

# %%
b = df.sort_values(by = "Low" , ascending = True).head(5)
b["Low"]
# Out:
# Date
# 2018-12-26    231.229996
# 2018-12-24    233.679993
# 2018-02-09    236.110001
# 2018-12-27    240.100006
# 2018-12-21    241.289993
# Name: Low, dtype: float64

# %% [markdown]
# TRENDS OVER HIGHS AND LOWS

# %%
fig, (ax1,ax2) = plt.subplots(nrows = 1 , ncols = 2 , sharex = True , figsize = (17,4))
fig.suptitle("HIGHS AND LOW TRENDS OVER TIME")
sns.lineplot(x = df.index , y = df["High"] , ax = ax1 , color = "green")
sns.lineplot(x = df.index , y = df["Low"] , ax = ax2 , color = "red")
# Out:
# <Axes: xlabel='Date', ylabel='Low'>
